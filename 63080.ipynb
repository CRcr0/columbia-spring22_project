# %%
# !git clone https://github.com/dddzg/up-detr.git
# Out:
# fatal: destination path 'up-detr' already exists and is not an empty directory.

# %%
# !pip install pycocotools
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %%
# !featurize dataset download 3e0ea0c3-7469-46c5-98af-6bd30875d187
# Out:
# Traceback (most recent call last):
#   File "/environment/miniconda3/bin/featurize", line 8, in <module>
#     sys.exit(cli())
#   File "/environment/miniconda3/lib/python3.7/site-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/environment/miniconda3/lib/python3.7/site-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/environment/miniconda3/lib/python3.7/site-packages/click/core.py", line 1259, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/environment/miniconda3/lib/python3.7/site-packages/click/core.py", line 1259, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/environment/miniconda3/lib/python3.7/site-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/environment/miniconda3/lib/python3.7/site-packages/click/core.py", line 610, in invoke
# ...

# %%
# !featurize dataset download a72f21dd-1bbe-4ebf-866b-1260b59b0405
# Out:
# 100%|████████████████████████████████████████| 989M/989M [00:05<00:00, 167MiB/s]
# 🍬  下载完成，正在解压...
# 🏁  数据集已经成功添加

# %%
# !wget -O  "up-detr-pre-training-60ep-imagenet.pth" https://tmp-reach.vx-cdn.com/file-6272033e444bd/
# Out:
# --2022-05-04 12:38:48--  https://tmp-reach.vx-cdn.com/file-6272033e444bd/
# Connecting to 172.16.0.13:5848... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 170974211 (163M) [application/octet-stream]
# Saving to: ‘up-detr-pre-training-60ep-imagenet.pth’
#
# up-detr-pre-trainin 100%[===================>] 163.05M  9.19MB/s    in 28s
#
# 2022-05-04 12:39:18 (5.85 MB/s) - ‘up-detr-pre-training-60ep-imagenet.pth’ saved [170974211/170974211]

# %%
# !python up-detr/detr_main.py \
    --batch_size 2 \
    --eval \
    --no_aux_loss \
    --pre_norm \
    --coco_path data \
    --resume up-detr-pre-training-60ep-imagenet.pth
# Out:
# Not using distributed mode
# git:
#   sha: be066dfca5e8f1f35a4331490e8239b579bbf497, status: clean, branch: master
#
# Namespace(aux_loss=False, backbone='resnet50', batch_size=2, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, coco_path='data', dataset_file='coco', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=300, eval=True, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_queries=100, num_workers=2, output_dir='', position_embedding='sine', pre_norm=True, pretrain='', remove_difficult=False, resume='up-detr-pre-training-60ep-imagenet.pth', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)
# number of params: 41302880
# loading annotations into memory...
# Done (t=1.38s)
# creating index...
# ...

# %%
# !python -m torch.distributed.launch --nproc_per_node=6 --use_env up-detr/detr_main.py --lr_drop 200 --epochs 3 --lr_backbone 5e-5 --pre_norm --coco_path data --pretrain up-detr-pre-training-60ep-imagenet.pth  --output_dir up-detr/checkpoint
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 4): env://
# | distributed init (rank 2): env://
# | distributed init (rank 3): env://
# | distributed init (rank 0): env://
# ...

# %%
# !python up-detr/detr_main.py \
    --batch_size 2 \
    --eval \
    --no_aux_loss \
    --pre_norm \
    --coco_path data \
    --resume up-detr/checkpoint/checkpoint.pth
# Out:
# Not using distributed mode
# git:
#   sha: be066dfca5e8f1f35a4331490e8239b579bbf497, status: clean, branch: master
#
# Namespace(aux_loss=False, backbone='resnet50', batch_size=2, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, coco_path='data', dataset_file='coco', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=300, eval=True, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_queries=100, num_workers=2, output_dir='', position_embedding='sine', pre_norm=True, pretrain='', remove_difficult=False, resume='up-detr/checkpoint/checkpoint.pth', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)
# number of params: 41302880
# loading annotations into memory...
# Done (t=1.46s)
# creating index...
# ...
